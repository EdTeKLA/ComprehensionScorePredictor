# %%
from sentence_transformers import SentenceTransformer, util
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from scipy.stats import spearmanr
import torch

# %%
grade = '5'
corpus_path = f"../subtest_txt/gr{grade}_paragraphs.txt"
questions_path = f"../subtest_txt/gr{grade}_questions.txt"
scores_path = "../Gates.ReadComp_By-Item_Gr3-5(CM).xlsx"

questions = []

with open(questions_path,'r') as fp:
    while True:
        sub_questions = []
        next_line = fp.readline()
        while next_line and next_line != '\n':
            q = next_line
            a = fp.readline()
            sub_question = q + ' ' + a
            sub_question = sub_question.replace('\n', '')
            sub_questions.append(sub_question)
            next_line = fp.readline()
        questions.append(sub_questions)
        if not next_line:
            break

sub_tests = []
with open(corpus_path,'r') as fp:
    sub_test = fp.readline()
    while sub_test:
        sub_tests.append(sub_test)
        print(len(sub_test))
        sub_test = fp.readline()

model = SentenceTransformer('paraphrase-mpnet-base-v2')

#Change the length to 200
model.max_seq_length = 800

distances = []

for i, sub_questions in enumerate(questions):
    print("text:", sub_tests[i+1])
    sub_test_embed = model.encode(sub_tests[i+1], show_progress_bar=True)
    sub_questions_embed = model.encode(sub_questions)
    for j, question in enumerate(sub_questions_embed):
        print('question:', sub_questions[j])
        cos_sim = util.pytorch_cos_sim(question, sub_test_embed)
        cos_sim = float(cos_sim)
        print(cos_sim)
        distances.append(cos_sim)

df = pd.read_excel(scores_path)
score_per_question_means = []
for q_num in range(1,len(distances)+1):
    total_score = 0
    total_students = 0
    for i in df.index:
        if df[f"Gr{grade}.RC.Gates_"+"{:02d}".format(q_num)][i] == 1:
            total_score +=1
            total_students += 1
        if df[f"Gr{grade}.RC.Gates_"+"{:02d}".format(q_num)][i] in (0,2):
            total_students += 1
            
    score_per_question_means.append(total_score/total_students)

print(score_per_question_means)

cos_line, = plt.plot(np.arange(1,len(distances)+1),distances)#, label='cosine similarity')
score_line, = plt.plot(np.arange(1,len(score_per_question_means)+1), score_per_question_means)#,lable = 'average score')
# np.arange(1,len(score_per_question_means)+1), 
# np.arange(1,len(distances)+1),
plt.legend()
plt.show()
# print("Max Sequence Length:", model.max_seq_length)
# Out:
# 190
# 357
# 489
# 799
# 541
# 624
# 676
# 630
# 601
# 662
# 592
# 552
# 1
# text: At a club meeting Maria Luisa met a new girl. She told Maria Luisa that she had just come from Texas and would begin school in the fall. Maria Luisa could feel in her an eagerness and a fear and she understood it well. "I was like that, too," she thought. Then she wondered if she and this girl, Anna, would be friends. Maybe she would be able to help her.
# HBox(children=(HTML(value='Batches'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# question: The passage suggests that Maria Luisa wanted to help Anne, go to Texas, be president, join the club.
# 0.59461510181427
# question: Why was Anna afraid? She hated school. She was at a club. She didn't know what to expect. She live in a tough neighbourhood.
# 0.57768714427948
# question: Talking to Anne made Maria Luisa remember being in Texas. Her own feelings. Her sister. Her old friends.
# 0.6495895385742188
# text: An Aztec Story The great Quetzalcoatl, king of the western heaven, did not know what to feed the people. He asked, "What shall we give them to eat?" Then an enormous red ant came crawling across the western heaven. She was carrying kernels of bright-colored corn in her mouth. "That looks delicious," said Quetzalcoatl. "Where did you find it?" For a long time the ant would not say. But at last the ant gave up her secret. She pointed to Food Mountain. "There is where I found the corn!"
# HBox(children=(HTML(value='Batches'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# question: Quetzalcoatl needed food for himself. people. the king. the red ant.
# 0.6922168135643005
# question: When Quetzalcoatl first saw the ant, what was she doing? Going somewhere. Trying to hide. Eating. Pointing.
# 0.6649421453475952
# question: The ant did not want to tell how she grew the corn. what she did with the corn. where the corn came from. where she was carrying the corn.
# 0.5498437285423279
# text: It was spring when the dolphin came to our island. We didn't take much notice of him at first because groups of wild dolphins often passed by offshore. They sometimes swam alongside our speeding boat to catch a ride on the cresting bow wave. I loved to watch them play, but they always ignored me and never stayed long. This dolphin was different. He came alone. He swam along the shore chasing fish in the grassbeds, and he followed my father's dive boat as it carried groups of tourists to dive on the reef. Almost every day, the dolphin swam to the reef with the dive boat. He carefully watched the tourists dive, but he never got too close to them. "I think he's lonely," said my father. "He seems curious but also afraid. I want to get to know him, Laura, and perhaps I can become his friend."
# HBox(children=(HTML(value='Batches'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# question: Why didn't Laura watch the one dolphin at first? He never came near the boat. He ignored people. He was hard to see. She was used to seeing dolphins.
# 0.7843455672264099
# question: What did the groups of wild dolphins do? They swam next to the boat. They swam with Laura. They chased the other dolphin away. They watched the tourists diving.
# 0.6582886576652527
# question: How was one dolphin different from the others? He was faster than the others. He swam all by himself. He was smaller than the others. He liked to play in the bow wave.
# 0.5566321015357971
# question: What was the dolphin careful about? Not watching too long. No diving too deep. Staying far enough away. Always being at the reef.
# 0.6779433488845825
# question: What did Laura's father do for a living? He caught fish. He took people out to the reef. He trained dolphins. He took people from island to island.
# 0.49244117736816406
# text: Traveling by Stagecoach The name "stagecoach" comes from how the routes were traveled—in stages. Every twelve miles or so, the coach stopped, and the horses, which had been running fast for an hour or more, were replaced by a fresh team. Speed and reliability were important, for the main income for stagecoach operators came from carrying the mail. Passengers brought in extra money. Their luggage was hoisted on top or carried in the protected area behind the coach body. The mail was carried under the driver's seat so he could guard it.
# HBox(children=(HTML(value='Batches'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# question: Why did the horses go fast? The passengers were in a hurry. The mail had to be delivered. The routes were dangerous. The teams were waiting for them.
# 0.5479053258895874
# question: Which place was safest for important papers? Inside the coach. Beside the coach body. On top of the coach. Under the driver's seat.
# 0.2959195077419281
# question: Every twelve miles or so the coach stopped so that the driver could rest. the horses could eat. different horses could pull it. the passengers could bring in extra money.
# 0.6586086750030518
# text: Most of the water in clouds comes from the ocean. Then why doesn't it rain over the ocean and nowhere else? Before the water droplets in a cloud can get big enough and heavy enough to rain, the air where the cloud is must get cool enough for a lot of drops to come together. The ocean holds heat very well. The warm ocean does not get cold enough at night to cool the air over it. The land cools much more quickly. Clouds do not condense over the ocean unless cold air from land blows over the warm water. What usually happens is that the wind blows water vapor from the ocean over the land, where it is cooled into clouds.
# HBox(children=(HTML(value='Batches'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# question: It doesn't rain much over the ocean because the ocean is rough. heavy. warm. wet.
# 0.6051681041717529
# question: When the air is warm, the water droplets in a cloud stay apart. turn white. sink to the bottom. get bigger.
# 0.6487915515899658
# question: It is most likely to rain over the ocean when the air is still. ocean holds its heat. sun goes down. wind blows from the land.
# 0.688967764377594
# question: Water vapor from the ocean usually turns into clouds when it first rises. begins to fall. turns into steam. is blown over the land.
# 0.6278721690177917
# question: what happens at night? The ocean cools the air. The land cools the air. The air cools the ocean. The clouds cool the ocean.
# 0.5833290815353394
# text: One summer afternoon when I went to visit Grandmother, she was busy with her pottery. She was sitting on the floor on her green shawl, with her pottery all around her. In her hand was a small bowl, which she was polishing. I sat beside Grandmother to watch her smooth and polish the pottery. To smooth out the rough edges, she used a scrubbing pad. Then, dampening the pottery, she rubbed it with a small, smooth stone until it shone. Her hands at times would move swiftly and then slow down. While working, she sometimes hummed a song to herself. As I was sitting beside Grandmother, she didn't even glance at me for a long time because she was concentrating on her pottery.
# HBox(children=(HTML(value='Batches'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# question: What was Grandmother sitting on? A stool. A dirt floor. A rug. A piece of clothing.
# 0.6481288075447083
# question: Grandmother used a scrubbing pad to make the pottery clean. damp. smooth. old-looking.
# 0.6598345637321472
# question: Grandmother used water with the pottery to wash it. shine it. paint it. take off the rough edges.
# 0.6540784239768982
# question: While she was working, Grandmother seemed to be tired. sad. content. bored.
# 0.643034040927887
# question: While Grandmother worked, the author watched silently. helped grandmother. hummed a song. tried doing the same things.
# 0.6633058786392212
# question: Why didn't Grandmother look at the author? Grandmother had her eyes closed. Grandmother could not see well. The author was behind grandmother. Grandmother was paying attention to what she was doing.
# 0.45442795753479004
# text: Some ants act like partners with plants. The best-known partnership is with some kinds of acacia trees. These "ant" acacias have hollow thorns in which the ants live. The ants patrol the trees, ready to attack whatever creatures land there. Ants protect acacias from other plants, too. They chew up vines that try to climb the acacia trees. And they may even keep all other plants trimmed back for several feet around. In return for their protection, the ants get food as well as a place to live. They eat special pods that grow on the acacia's leaves. They also drink nectar produced in special glands at the base of the leaves.
# HBox(children=(HTML(value='Batches'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# question: The passage suggests that the creatures would be likely to eat some of the ants. attack the ants. patrol the trees. hurt the acacias.
# 0.640638530254364
# question: Why are the ants and acacias called partners? They help each other. They live at the same time. They do not hurt each other. They need the same things.
# 0.7555498480796814
# question: Where do the ants live? In the pods. On the vines. Inside the stems. Inside the thorns.
# 0.5072836875915527
# question: By chewing on vines, the ants get a special food. keep the vines off the trees. help the vines grow quickly. make the vines stronger.
# 0.6427081823348999
# question: The passage suggests that acacia trees do not grow well if the leaves produce pods. only ants live on them. other plants are growing close by. they have too many ants.
# 0.5600801706314087
# No handles with labels found to put in legend.
# [0.8148148148148148, 0.5925925925925926, 0.5648148148148148, 0.8425925925925926, 0.3888888888888889, 0.8240740740740741, 0.35185185185185186, 0.7222222222222222, 0.75, 0.5833333333333334, 0.6944444444444444, 0.5925925925925926, 0.6574074074074074, 0.5833333333333334, 0.6944444444444444, 0.3148148148148148, 0.4537037037037037, 0.3888888888888889, 0.17592592592592593, 0.2777777777777778, 0.7222222222222222, 0.4166666666666667, 0.7407407407407407, 0.6851851851851852, 0.8703703703703703, 0.3425925925925926, 0.5925925925925926, 0.5740740740740741, 0.5277777777777778, 0.5277777777777778]

# %%
distances = np.array(distances)
score_per_question_means = np.array(score_per_question_means)

plt.figure(figsize=(12, 6))
x1 = np.arange(1,len(distances)+1)
y1 = 1 - distances
plt.plot(x1,y1, 'o-',label='1 - cosine sim')
x2 = np.arange(1,len(score_per_question_means)+1)
y2 = score_per_question_means
plt.plot(x2, y2,'o-',label='average score')
plt.xticks(np.arange(0, len(distances)+1, step=1))
plt.xlabel('question number')

# Set a title of the current axes.
plt.legend()
plt.show()

# %%
# https://machinelearningmastery.com/how-to-use-correlation-to-understand-the-relationship-between-variables/
print(score_per_question_means.shape)
print(distances.shape)
print(score_per_question_means)
corr, _ = spearmanr(distances, score_per_question_means)

print("Spearman's correlation: %.3f" % corr)
# Out:
# (30,)
# (30,)
# [0.81481481 0.59259259 0.56481481 0.84259259 0.38888889 0.82407407
#  0.35185185 0.72222222 0.75       0.58333333 0.69444444 0.59259259
#  0.65740741 0.58333333 0.69444444 0.31481481 0.4537037  0.38888889
#  0.17592593 0.27777778 0.72222222 0.41666667 0.74074074 0.68518519
#  0.87037037 0.34259259 0.59259259 0.57407407 0.52777778 0.52777778]
# Spearman's correlation: -0.236
